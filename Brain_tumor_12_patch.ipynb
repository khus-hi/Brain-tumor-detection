# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import multilabel_confusion_matrix,confusion_matrix
import seaborn as sns
from sklearn.model_selection   import train_test_split

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense,Add, Dropout, Resizing,Rescaling,InputLayer,Flatten,LayerNormalization, MultiHeadAttention

from tensorflow.keras.callbacks import Callback, EarlyStopping,ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers,Model
from tensorflow.keras.regularizers import L2
from tensorflow.keras.metrics import CategoricalAccuracy, TopKCategoricalAccuracy

from tensorflow.keras.preprocessing.image import load_img
#from tensorflow.keras.utils import plot_model
from functools import partial

# %%
import pandas as pd
#import plotly.express as px
from tensorflow.keras.layers import RandomRotation, RandomFlip, RandomContrast
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
learning_rate = 0.0001
class_name=['glioma','meningioma','notumor','pituitary']
#class_name = ['glioma_tumor', 'meningioma_tumor', 'no_tumor', 'pituitary_tumor']
weight_decay = 0.0001
num_classes=4
batch_size =32
num_epochs = 120
image_size = 225  # We'll resize input images to this size
patch_size = 12  # Size of the patches to be extract from the input images
num_patches = (image_size // patch_size) ** 2
projection_dim = 64
Num_heads = 4
transformer_units = [
    projection_dim * 2,
    projection_dim,
]  # Size of the transformer layers
num_layers = 15
Hidden_size=64
mlp_head_units = 1024

# %% [markdown]
# importing from drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile
import os

# Step 1: Extract the ZIP file to a specific folder
with zipfile.ZipFile('/content/drive/MyDrive/archive (5).zip', 'r') as zip_ref:
    zip_ref.extractall('/content/temp')

# Step 2: List the files in the extracted folder
os.listdir('/content/temp')

# Step 3: Refresh the File Explorer manually or list files again
# Out:
# ['Training', 'Testing']

# %%
# !ls /content/
# !ls /content/temp
# Out:
# drive  sample_data  temp
# Testing  Training

# %%
train_data = r'/content/temp/Training'
test_data = r'/content/temp/Testing'

# %%
train_dataset = tf.keras.utils.image_dataset_from_directory(
    train_data,
    labels='inferred',
    label_mode='categorical',
    class_names=class_name,
    color_mode='grayscale',
    batch_size=batch_size,
    image_size=(image_size,image_size),
    shuffle=True,
    seed=99,
    validation_split=0.2,
    subset='training',
)
val_dataset = tf.keras.utils.image_dataset_from_directory(
    train_data,
    labels='inferred',
    label_mode='categorical',
    class_names=class_name,
    color_mode='grayscale',
    batch_size=batch_size,
    image_size=(image_size,image_size),
    shuffle=True,
    seed=99,
    validation_split=0.2,  # Use 20% of the data for validation
    subset='validation',
)
test_dataset = tf.keras.utils.image_dataset_from_directory(
    test_data,
    labels='inferred',
    label_mode='categorical',
    class_names=class_name,
    color_mode='grayscale',
    batch_size=batch_size,
    image_size=(image_size,image_size),
    shuffle=True,
    seed=99,
)
# Out:
# Found 5712 files belonging to 4 classes.
# Using 4570 files for training.
# Found 5712 files belonging to 4 classes.
# Using 1142 files for validation.
# Found 1311 files belonging to 4 classes.

# %%
plt.figure(figsize=(8, 8))
for images, labels in train_dataset.take(10):
    for i in range(min(16, len(images))):
        ax = plt.subplot(4, 4, i + 1)
        plt.imshow(images[i] / 255., cmap='gray')
        plt.title(class_name[tf.argmax(labels[i]).numpy()])
        plt.axis("off")

plt.show()

# %%
augment_layers = tf.keras.Sequential([
    RandomRotation(factor=(-0.25, 0.2501)),
   RandomFlip("horizontal_and_vertical",seed=42),  # Specify a seed for reproducibility
])

# %%
# Define a custom preprocessing function
def process_data(image, label):
    augmented_image=augment_layers(image)
    resized_image = tf.image.resize(augmented_image, size=(image_size, image_size))
    return resized_image, label

# Apply augmentation and preprocessing to the dataset
training_dataset = (
    train_dataset.
    shuffle(1000)
    .map(partial(process_data),num_parallel_calls=tf.data.AUTOTUNE)
    .prefetch(tf.data.AUTOTUNE)
)

# %%
vali_dataset=(
   val_dataset.shuffle(1000)
    .prefetch(tf.data.AUTOTUNE)


)

# %%
input_tensor = next(iter(training_dataset))[0]

# %%
patche=tf.image.extract_patches(images=input_tensor,
                               sizes=[1,patch_size,patch_size,1],
                                strides=[1,patch_size,patch_size,1],
                                rates=[1,1,1,1],
                                 padding='VALID')

# %%
plt.figure(figsize=(12, 12))

batch_size, patch_rows, patch_cols, channels = patche.shape
plt.subplot(1, 2, 1)
plt.imshow(input_tensor[0],cmap='gray')
plt.title('Original Image')
plt.axis('off')
plt.show()
for i in range(patch_rows):
    for j in range(patch_cols):
        ax = plt.subplot(patch_rows, patch_cols, i * patch_cols + j + 1)
        plt.imshow(patche[0, i, j, :].numpy().reshape (patch_size,patch_size, 1),cmap='gray')
        plt.axis("off")

plt.show()

# %%
class PatchEncoder(layers.Layer):
    def __init__(self, patch_size,Hidden_size):
        super(PatchEncoder, self).__init__(name='patch_encoder')
        self.linear_projection=Dense(Hidden_size)
        self.position_embedding = layers.Embedding(
            input_dim=num_patches, output_dim=Hidden_size
        )

        self.num_patches=num_patches

    def call(self, image):
        batch_size = tf.shape(image)[0]  # Retrieve batch size
        patches=tf.image.extract_patches(images=image,
                                sizes=[1,patch_size,patch_size,1],
                                strides=[1,patch_size,patch_size,1],
                                rates=[1,1,1,1],
                                 padding='VALID'
                                )

        patch_dims = patches.shape[-1]
        patches = tf.reshape(patches, [batch_size, -1, patches.shape[-1]])
        embedding_input=tf.range(start=0,limit =self.num_patches,delta=1)
        output=self.linear_projection(patches)+ self.position_embedding(embedding_input)
        return output

# %%
class TransformerEncoder(layers.Layer):
    def __init__(self, Num_heads,Hidden_size):
        super(TransformerEncoder, self).__init__(name='transformer_encoder')
        self.layer_norm_1=LayerNormalization()
        self.layer_norm_2=LayerNormalization()

        self.multi_head_att=MultiHeadAttention(Num_heads,Hidden_size)

        self.dense_1=Dense(Hidden_size,activation=tf.nn.gelu)
        self.dense_2=Dense(Hidden_size,activation=tf.nn.gelu)


    def call(self, input):
        x=self.layer_norm_1(input)
        x1=self.multi_head_att(x,x)

        x1=Add()([x1,input])
        x2=self.layer_norm_2(x1)
        x2=self.dense_1(x2)
        output=self.dense_1(x2)
        output=Add()([output,x1])

        return output

# %%
class VIT(tf.keras.Model):
    def __init__(self, Num_heads, Hidden_size, num_patches, num_layers, mlp_head_units):
        super(VIT, self).__init__(name='vision_transformer')
        self.num_layers = num_layers
        self.patch_encoder = PatchEncoder(patch_size, Hidden_size)
        self.trans_encoder = [TransformerEncoder(Num_heads, Hidden_size) for _ in range(num_layers)]
        self.flatten = layers.Flatten()
        self.dense_1 = layers.Dense(mlp_head_units, activation='relu')
        self.dense_2 = layers.Dense(mlp_head_units, activation='relu')
        self.dense_3 = layers.Dense(num_classes, activation='softmax')

    def call(self, inputs):
        x = self.patch_encoder(inputs)  # Get encoded patches
        for i in range(self.num_layers):
            x = self.trans_encoder[i](x)  # Apply transformer encoder layers

        x = self.flatten(x)
        x = self.dense_1(x)
        x = self.dense_2(x)
        output = self.dense_3(x)
        return output

# Create and compile the VIT model
vit = VIT(Num_heads, Hidden_size, num_patches, num_layers, mlp_head_units)

# %%
loss_funcion=tf.keras.losses.CategoricalCrossentropy(
    from_logits=False,

)

# %%
metrics=[CategoricalAccuracy(name= 'accuracy'),TopKCategoricalAccuracy(k=2,name='top_k_accuracy')]

# %%
vit.compile(
    optimizer=Adam(learning_rate=learning_rate),
                   loss=loss_funcion,
                   metrics=metrics

)

# %%
# Define the filepath to save the model weights
checkpoint_filepath = "/kaggle/working/checkpoint.weights.h5"

# Define the ModelCheckpoint callback
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    checkpoint_filepath,
    monitor="val_accuracy",
    save_best_only=True,
    save_weights_only=True
)

# %%
# Train the model
history = vit.fit(
    training_dataset,
    epochs=num_epochs,
    verbose=1,
    validation_data=vali_dataset,
    callbacks=[checkpoint_callback]

)
# Out:
# Epoch 1/120
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/layer.py:372: UserWarning: `build()` was called on layer 'transformer_encoder', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 140s 498ms/step - accuracy: 0.3685 - loss: 90.9137 - top_k_accuracy: 0.7158 - val_accuracy: 0.5359 - val_loss: 8.4217 - val_top_k_accuracy: 0.7706
# Epoch 2/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 74s 198ms/step - accuracy: 0.5230 - loss: 7.5485 - top_k_accuracy: 0.7732 - val_accuracy: 0.5788 - val_loss: 3.6256 - val_top_k_accuracy: 0.8459
# Epoch 3/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 43s 213ms/step - accuracy: 0.6108 - loss: 3.8914 - top_k_accuracy: 0.8245 - val_accuracy: 0.6716 - val_loss: 2.3867 - val_top_k_accuracy: 0.8774
# Epoch 4/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 30s 186ms/step - accuracy: 0.6021 - loss: 3.0336 - top_k_accuracy: 0.8333 - val_accuracy: 0.6375 - val_loss: 2.2096 - val_top_k_accuracy: 0.8643
# Epoch 5/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 41s 187ms/step - accuracy: 0.6301 - loss: 2.1796 - top_k_accuracy: 0.8564 - val_accuracy: 0.5919 - val_loss: 1.9327 - val_top_k_accuracy: 0.8450
# Epoch 6/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 33s 205ms/step - accuracy: 0.6467 - loss: 1.8792 - top_k_accuracy: 0.8572 - val_accuracy: 0.6445 - val_loss: 1.9121 - val_top_k_accuracy: 0.8415
# Epoch 7/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 38s 186ms/step - accuracy: 0.6398 - loss: 1.6190 - top_k_accuracy: 0.8578 - val_accuracy: 0.5998 - val_loss: 1.8889 - val_top_k_accuracy: 0.8739
# Epoch 8/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 33s 206ms/step - accuracy: 0.6665 - loss: 1.3664 - top_k_accuracy: 0.8849 - val_accuracy: 0.6567 - val_loss: 1.5675 - val_top_k_accuracy: 0.8546
# Epoch 9/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 38s 186ms/step - accuracy: 0.6863 - loss: 1.3841 - top_k_accuracy: 0.8814 - val_accuracy: 0.6541 - val_loss: 1.3174 - val_top_k_accuracy: 0.8897
# Epoch 10/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 31s 193ms/step - accuracy: 0.6807 - loss: 1.2325 - top_k_accuracy: 0.8891 - val_accuracy: 0.6532 - val_loss: 1.2701 - val_top_k_accuracy: 0.8870
# Epoch 11/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 40s 185ms/step - accuracy: 0.7152 - loss: 0.9952 - top_k_accuracy: 0.9064 - val_accuracy: 0.6611 - val_loss: 1.3298 - val_top_k_accuracy: 0.8730
# Epoch 12/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 43s 200ms/step - accuracy: 0.6847 - loss: 1.1812 - top_k_accuracy: 0.8940 - val_accuracy: 0.6953 - val_loss: 0.9907 - val_top_k_accuracy: 0.9107
# Epoch 13/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 41s 200ms/step - accuracy: 0.6979 - loss: 1.0402 - top_k_accuracy: 0.9024 - val_accuracy: 0.7356 - val_loss: 0.8659 - val_top_k_accuracy: 0.9273
# Epoch 14/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 30s 188ms/step - accuracy: 0.7238 - loss: 0.9108 - top_k_accuracy: 0.9124 - val_accuracy: 0.7224 - val_loss: 1.0722 - val_top_k_accuracy: 0.9089
# Epoch 15/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 30s 186ms/step - accuracy: 0.7184 - loss: 0.9834 - top_k_accuracy: 0.9066 - val_accuracy: 0.7303 - val_loss: 0.8791 - val_top_k_accuracy: 0.9387
# Epoch 16/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 41s 186ms/step - accuracy: 0.7410 - loss: 0.8862 - top_k_accuracy: 0.9213 - val_accuracy: 0.6541 - val_loss: 1.3378 - val_top_k_accuracy: 0.9256
# Epoch 17/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 43s 197ms/step - accuracy: 0.7342 - loss: 0.9093 - top_k_accuracy: 0.9198 - val_accuracy: 0.7382 - val_loss: 0.9085 - val_top_k_accuracy: 0.9308
# Epoch 18/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 33s 197ms/step - accuracy: 0.7558 - loss: 0.8214 - top_k_accuracy: 0.9368 - val_accuracy: 0.7408 - val_loss: 1.0032 - val_top_k_accuracy: 0.9177
# Epoch 19/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 40s 196ms/step - accuracy: 0.7558 - loss: 0.8360 - top_k_accuracy: 0.9296 - val_accuracy: 0.7496 - val_loss: 0.8952 - val_top_k_accuracy: 0.9273
# Epoch 20/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 41s 197ms/step - accuracy: 0.7746 - loss: 0.7714 - top_k_accuracy: 0.9326 - val_accuracy: 0.7522 - val_loss: 0.8473 - val_top_k_accuracy: 0.9440
# Epoch 21/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 41s 197ms/step - accuracy: 0.7789 - loss: 0.7480 - top_k_accuracy: 0.9452 - val_accuracy: 0.7767 - val_loss: 0.7725 - val_top_k_accuracy: 0.9405
# Epoch 22/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 40s 189ms/step - accuracy: 0.7845 - loss: 0.7147 - top_k_accuracy: 0.9384 - val_accuracy: 0.7671 - val_loss: 0.7859 - val_top_k_accuracy: 0.9448
# Epoch 23/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 41s 187ms/step - accuracy: 0.7991 - loss: 0.6856 - top_k_accuracy: 0.9448 - val_accuracy: 0.7504 - val_loss: 0.9160 - val_top_k_accuracy: 0.9317
# Epoch 24/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 41s 187ms/step - accuracy: 0.7853 - loss: 0.7242 - top_k_accuracy: 0.9449 - val_accuracy: 0.7399 - val_loss: 0.8743 - val_top_k_accuracy: 0.9440
# Epoch 25/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 41s 189ms/step - accuracy: 0.8052 - loss: 0.6588 - top_k_accuracy: 0.9521 - val_accuracy: 0.7434 - val_loss: 0.8557 - val_top_k_accuracy: 0.9641
# Epoch 26/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 42s 196ms/step - accuracy: 0.7903 - loss: 0.7204 - top_k_accuracy: 0.9450 - val_accuracy: 0.7855 - val_loss: 0.7929 - val_top_k_accuracy: 0.9378
# Epoch 27/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 40s 187ms/step - accuracy: 0.7983 - loss: 0.6553 - top_k_accuracy: 0.9542 - val_accuracy: 0.7531 - val_loss: 0.8359 - val_top_k_accuracy: 0.9457
# Epoch 28/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 41s 187ms/step - accuracy: 0.8060 - loss: 0.6505 - top_k_accuracy: 0.9613 - val_accuracy: 0.7277 - val_loss: 0.9415 - val_top_k_accuracy: 0.9335
# Epoch 29/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 30s 187ms/step - accuracy: 0.8230 - loss: 0.5887 - top_k_accuracy: 0.9680 - val_accuracy: 0.7364 - val_loss: 0.8672 - val_top_k_accuracy: 0.9553
# Epoch 30/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 30s 186ms/step - accuracy: 0.7977 - loss: 0.7444 - top_k_accuracy: 0.9439 - val_accuracy: 0.7539 - val_loss: 0.9435 - val_top_k_accuracy: 0.9370
# Epoch 31/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 41s 188ms/step - accuracy: 0.8041 - loss: 0.6021 - top_k_accuracy: 0.9611 - val_accuracy: 0.7697 - val_loss: 0.7896 - val_top_k_accuracy: 0.9501
# Epoch 32/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 30s 188ms/step - accuracy: 0.8275 - loss: 0.6170 - top_k_accuracy: 0.9657 - val_accuracy: 0.7548 - val_loss: 0.7839 - val_top_k_accuracy: 0.9597
# Epoch 33/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 43s 202ms/step - accuracy: 0.8224 - loss: 0.5721 - top_k_accuracy: 0.9685 - val_accuracy: 0.7767 - val_loss: 0.8117 - val_top_k_accuracy: 0.9562
# Epoch 34/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 34s 207ms/step - accuracy: 0.8224 - loss: 0.5756 - top_k_accuracy: 0.9645 - val_accuracy: 0.7461 - val_loss: 0.8539 - val_top_k_accuracy: 0.9571
# Epoch 35/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 30s 186ms/step - accuracy: 0.8149 - loss: 0.6431 - top_k_accuracy: 0.9669 - val_accuracy: 0.7548 - val_loss: 0.7777 - val_top_k_accuracy: 0.9606
# Epoch 36/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 31s 194ms/step - accuracy: 0.8238 - loss: 0.5350 - top_k_accuracy: 0.9707 - val_accuracy: 0.7522 - val_loss: 0.8042 - val_top_k_accuracy: 0.9527
# Epoch 37/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 40s 186ms/step - accuracy: 0.8324 - loss: 0.5726 - top_k_accuracy: 0.9730 - val_accuracy: 0.7531 - val_loss: 0.9731 - val_top_k_accuracy: 0.9378
# Epoch 38/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 45s 214ms/step - accuracy: 0.8230 - loss: 0.5974 - top_k_accuracy: 0.9656 - val_accuracy: 0.7933 - val_loss: 0.8047 - val_top_k_accuracy: 0.9545
# Epoch 39/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 37s 186ms/step - accuracy: 0.8408 - loss: 0.5375 - top_k_accuracy: 0.9760 - val_accuracy: 0.7855 - val_loss: 0.7720 - val_top_k_accuracy: 0.9553
# Epoch 40/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 43s 198ms/step - accuracy: 0.8392 - loss: 0.5661 - top_k_accuracy: 0.9658 - val_accuracy: 0.8047 - val_loss: 0.6498 - val_top_k_accuracy: 0.9615
# Epoch 41/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 30s 188ms/step - accuracy: 0.8516 - loss: 0.5027 - top_k_accuracy: 0.9700 - val_accuracy: 0.8030 - val_loss: 0.6882 - val_top_k_accuracy: 0.9606
# Epoch 42/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 41s 187ms/step - accuracy: 0.8499 - loss: 0.4873 - top_k_accuracy: 0.9707 - val_accuracy: 0.8030 - val_loss: 0.6849 - val_top_k_accuracy: 0.9597
# Epoch 43/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 43s 198ms/step - accuracy: 0.8361 - loss: 0.5498 - top_k_accuracy: 0.9672 - val_accuracy: 0.8074 - val_loss: 0.6557 - val_top_k_accuracy: 0.9606
# Epoch 44/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 40s 197ms/step - accuracy: 0.8482 - loss: 0.4758 - top_k_accuracy: 0.9689 - val_accuracy: 0.8170 - val_loss: 0.6845 - val_top_k_accuracy: 0.9667
# Epoch 45/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 41s 196ms/step - accuracy: 0.8618 - loss: 0.4783 - top_k_accuracy: 0.9762 - val_accuracy: 0.8231 - val_loss: 0.6871 - val_top_k_accuracy: 0.9562
# Epoch 46/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 32s 195ms/step - accuracy: 0.8456 - loss: 0.5088 - top_k_accuracy: 0.9723 - val_accuracy: 0.8266 - val_loss: 0.6512 - val_top_k_accuracy: 0.9597
# Epoch 47/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 40s 186ms/step - accuracy: 0.8736 - loss: 0.4457 - top_k_accuracy: 0.9748 - val_accuracy: 0.8030 - val_loss: 0.6614 - val_top_k_accuracy: 0.9632
# Epoch 48/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 41s 188ms/step - accuracy: 0.8699 - loss: 0.4146 - top_k_accuracy: 0.9747 - val_accuracy: 0.8144 - val_loss: 0.6278 - val_top_k_accuracy: 0.9764
# Epoch 49/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 32s 202ms/step - accuracy: 0.8615 - loss: 0.4516 - top_k_accuracy: 0.9785 - val_accuracy: 0.8249 - val_loss: 0.5377 - val_top_k_accuracy: 0.9737
# Epoch 50/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 39s 186ms/step - accuracy: 0.8538 - loss: 0.4535 - top_k_accuracy: 0.9697 - val_accuracy: 0.8179 - val_loss: 0.6512 - val_top_k_accuracy: 0.9667
# Epoch 51/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 31s 192ms/step - accuracy: 0.8427 - loss: 0.5302 - top_k_accuracy: 0.9708 - val_accuracy: 0.8161 - val_loss: 0.7147 - val_top_k_accuracy: 0.9720
# Epoch 52/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 30s 185ms/step - accuracy: 0.8685 - loss: 0.4281 - top_k_accuracy: 0.9790 - val_accuracy: 0.8161 - val_loss: 0.6293 - val_top_k_accuracy: 0.9694
# Epoch 53/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 32s 196ms/step - accuracy: 0.8682 - loss: 0.4074 - top_k_accuracy: 0.9789 - val_accuracy: 0.8336 - val_loss: 0.6484 - val_top_k_accuracy: 0.9694
# Epoch 54/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 32s 185ms/step - accuracy: 0.8739 - loss: 0.4035 - top_k_accuracy: 0.9826 - val_accuracy: 0.8266 - val_loss: 0.5836 - val_top_k_accuracy: 0.9764
# Epoch 55/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 41s 186ms/step - accuracy: 0.8692 - loss: 0.4370 - top_k_accuracy: 0.9774 - val_accuracy: 0.8240 - val_loss: 0.7087 - val_top_k_accuracy: 0.9606
# Epoch 56/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 49s 245ms/step - accuracy: 0.8607 - loss: 0.4243 - top_k_accuracy: 0.9805 - val_accuracy: 0.8503 - val_loss: 0.5523 - val_top_k_accuracy: 0.9685
# Epoch 57/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 32s 187ms/step - accuracy: 0.8783 - loss: 0.4066 - top_k_accuracy: 0.9787 - val_accuracy: 0.7680 - val_loss: 0.9055 - val_top_k_accuracy: 0.9737
# Epoch 58/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 31s 187ms/step - accuracy: 0.8751 - loss: 0.3744 - top_k_accuracy: 0.9844 - val_accuracy: 0.7469 - val_loss: 0.9418 - val_top_k_accuracy: 0.9440
# Epoch 59/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 40s 186ms/step - accuracy: 0.8633 - loss: 0.4497 - top_k_accuracy: 0.9759 - val_accuracy: 0.8363 - val_loss: 0.5929 - val_top_k_accuracy: 0.9702
# Epoch 60/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 42s 191ms/step - accuracy: 0.8671 - loss: 0.3985 - top_k_accuracy: 0.9768 - val_accuracy: 0.8459 - val_loss: 0.5922 - val_top_k_accuracy: 0.9729
# Epoch 61/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 39s 236ms/step - accuracy: 0.8775 - loss: 0.3939 - top_k_accuracy: 0.9807 - val_accuracy: 0.8590 - val_loss: 0.4942 - val_top_k_accuracy: 0.9764
# Epoch 62/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 33s 203ms/step - accuracy: 0.8727 - loss: 0.3531 - top_k_accuracy: 0.9826 - val_accuracy: 0.8214 - val_loss: 0.5431 - val_top_k_accuracy: 0.9746
# Epoch 63/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 39s 187ms/step - accuracy: 0.8635 - loss: 0.4309 - top_k_accuracy: 0.9837 - val_accuracy: 0.8310 - val_loss: 0.6124 - val_top_k_accuracy: 0.9676
# Epoch 64/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 34s 202ms/step - accuracy: 0.8673 - loss: 0.3696 - top_k_accuracy: 0.9800 - val_accuracy: 0.8363 - val_loss: 0.5196 - val_top_k_accuracy: 0.9772
# Epoch 65/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 40s 202ms/step - accuracy: 0.8770 - loss: 0.3753 - top_k_accuracy: 0.9852 - val_accuracy: 0.7653 - val_loss: 0.9502 - val_top_k_accuracy: 0.9667
# Epoch 66/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 39s 188ms/step - accuracy: 0.8760 - loss: 0.3778 - top_k_accuracy: 0.9831 - val_accuracy: 0.8240 - val_loss: 0.5268 - val_top_k_accuracy: 0.9755
# Epoch 67/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 31s 184ms/step - accuracy: 0.8758 - loss: 0.3549 - top_k_accuracy: 0.9846 - val_accuracy: 0.7916 - val_loss: 0.8635 - val_top_k_accuracy: 0.9650
# Epoch 68/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 32s 190ms/step - accuracy: 0.8733 - loss: 0.3891 - top_k_accuracy: 0.9823 - val_accuracy: 0.8222 - val_loss: 0.5383 - val_top_k_accuracy: 0.9694
# Epoch 69/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 31s 193ms/step - accuracy: 0.8752 - loss: 0.3659 - top_k_accuracy: 0.9832 - val_accuracy: 0.8485 - val_loss: 0.4577 - val_top_k_accuracy: 0.9720
# Epoch 70/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 42s 202ms/step - accuracy: 0.8871 - loss: 0.3324 - top_k_accuracy: 0.9854 - val_accuracy: 0.8275 - val_loss: 0.6247 - val_top_k_accuracy: 0.9580
# Epoch 71/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 30s 188ms/step - accuracy: 0.8774 - loss: 0.3709 - top_k_accuracy: 0.9840 - val_accuracy: 0.8459 - val_loss: 0.4852 - val_top_k_accuracy: 0.9658
# Epoch 72/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 40s 184ms/step - accuracy: 0.8770 - loss: 0.3571 - top_k_accuracy: 0.9767 - val_accuracy: 0.8371 - val_loss: 0.5621 - val_top_k_accuracy: 0.9641
# Epoch 73/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 41s 187ms/step - accuracy: 0.8708 - loss: 0.3838 - top_k_accuracy: 0.9796 - val_accuracy: 0.8074 - val_loss: 0.9526 - val_top_k_accuracy: 0.9623
# Epoch 74/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 32s 202ms/step - accuracy: 0.8902 - loss: 0.3122 - top_k_accuracy: 0.9878 - val_accuracy: 0.8240 - val_loss: 0.5748 - val_top_k_accuracy: 0.9790
# Epoch 75/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 31s 184ms/step - accuracy: 0.8886 - loss: 0.3070 - top_k_accuracy: 0.9863 - val_accuracy: 0.8511 - val_loss: 0.4571 - val_top_k_accuracy: 0.9825
# Epoch 76/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 43s 202ms/step - accuracy: 0.8922 - loss: 0.2907 - top_k_accuracy: 0.9884 - val_accuracy: 0.8581 - val_loss: 0.4785 - val_top_k_accuracy: 0.9781
# Epoch 77/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 32s 200ms/step - accuracy: 0.8781 - loss: 0.3734 - top_k_accuracy: 0.9818 - val_accuracy: 0.8292 - val_loss: 0.5480 - val_top_k_accuracy: 0.9781
# Epoch 78/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 31s 189ms/step - accuracy: 0.8796 - loss: 0.3513 - top_k_accuracy: 0.9884 - val_accuracy: 0.8336 - val_loss: 0.5468 - val_top_k_accuracy: 0.9764
# Epoch 79/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 32s 203ms/step - accuracy: 0.8829 - loss: 0.3296 - top_k_accuracy: 0.9881 - val_accuracy: 0.8634 - val_loss: 0.4781 - val_top_k_accuracy: 0.9755
# Epoch 80/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 32s 184ms/step - accuracy: 0.8821 - loss: 0.3385 - top_k_accuracy: 0.9873 - val_accuracy: 0.8564 - val_loss: 0.5076 - val_top_k_accuracy: 0.9816
# Epoch 81/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 41s 186ms/step - accuracy: 0.8929 - loss: 0.2882 - top_k_accuracy: 0.9888 - val_accuracy: 0.8406 - val_loss: 0.6149 - val_top_k_accuracy: 0.9729
# Epoch 82/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 32s 185ms/step - accuracy: 0.8800 - loss: 0.3380 - top_k_accuracy: 0.9804 - val_accuracy: 0.8345 - val_loss: 0.5172 - val_top_k_accuracy: 0.9772
# Epoch 83/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 33s 200ms/step - accuracy: 0.8940 - loss: 0.3072 - top_k_accuracy: 0.9839 - val_accuracy: 0.8389 - val_loss: 0.4782 - val_top_k_accuracy: 0.9807
# Epoch 84/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 40s 189ms/step - accuracy: 0.8846 - loss: 0.3272 - top_k_accuracy: 0.9887 - val_accuracy: 0.8424 - val_loss: 0.4722 - val_top_k_accuracy: 0.9764
# Epoch 85/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 32s 200ms/step - accuracy: 0.9028 - loss: 0.2562 - top_k_accuracy: 0.9913 - val_accuracy: 0.8695 - val_loss: 0.4938 - val_top_k_accuracy: 0.9764
# Epoch 86/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 30s 185ms/step - accuracy: 0.8841 - loss: 0.3302 - top_k_accuracy: 0.9857 - val_accuracy: 0.8643 - val_loss: 0.4627 - val_top_k_accuracy: 0.9869
# Epoch 87/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 41s 188ms/step - accuracy: 0.8936 - loss: 0.3121 - top_k_accuracy: 0.9856 - val_accuracy: 0.8301 - val_loss: 0.6325 - val_top_k_accuracy: 0.9746
# Epoch 88/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 41s 187ms/step - accuracy: 0.8934 - loss: 0.3278 - top_k_accuracy: 0.9839 - val_accuracy: 0.8441 - val_loss: 0.5566 - val_top_k_accuracy: 0.9685
# Epoch 89/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 30s 186ms/step - accuracy: 0.9050 - loss: 0.2930 - top_k_accuracy: 0.9863 - val_accuracy: 0.8450 - val_loss: 0.5382 - val_top_k_accuracy: 0.9816
# Epoch 90/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 30s 185ms/step - accuracy: 0.8972 - loss: 0.2969 - top_k_accuracy: 0.9887 - val_accuracy: 0.8608 - val_loss: 0.4328 - val_top_k_accuracy: 0.9816
# Epoch 91/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 47s 225ms/step - accuracy: 0.8867 - loss: 0.3080 - top_k_accuracy: 0.9862 - val_accuracy: 0.8774 - val_loss: 0.4410 - val_top_k_accuracy: 0.9869
# Epoch 92/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 36s 187ms/step - accuracy: 0.8979 - loss: 0.2974 - top_k_accuracy: 0.9854 - val_accuracy: 0.8389 - val_loss: 0.6268 - val_top_k_accuracy: 0.9676
# Epoch 93/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 30s 185ms/step - accuracy: 0.8949 - loss: 0.3054 - top_k_accuracy: 0.9877 - val_accuracy: 0.8284 - val_loss: 0.6521 - val_top_k_accuracy: 0.9746
# Epoch 94/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 41s 185ms/step - accuracy: 0.9039 - loss: 0.2831 - top_k_accuracy: 0.9898 - val_accuracy: 0.8450 - val_loss: 0.4839 - val_top_k_accuracy: 0.9869
# Epoch 95/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 33s 205ms/step - accuracy: 0.9114 - loss: 0.2667 - top_k_accuracy: 0.9871 - val_accuracy: 0.8687 - val_loss: 0.4432 - val_top_k_accuracy: 0.9860
# Epoch 96/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 33s 199ms/step - accuracy: 0.9075 - loss: 0.2482 - top_k_accuracy: 0.9916 - val_accuracy: 0.8573 - val_loss: 0.5707 - val_top_k_accuracy: 0.9737
# Epoch 97/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 42s 206ms/step - accuracy: 0.8911 - loss: 0.3208 - top_k_accuracy: 0.9872 - val_accuracy: 0.8152 - val_loss: 0.6040 - val_top_k_accuracy: 0.9799
# Epoch 98/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 32s 202ms/step - accuracy: 0.9076 - loss: 0.2676 - top_k_accuracy: 0.9930 - val_accuracy: 0.8765 - val_loss: 0.3868 - val_top_k_accuracy: 0.9842
# Epoch 99/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 40s 188ms/step - accuracy: 0.9094 - loss: 0.2634 - top_k_accuracy: 0.9919 - val_accuracy: 0.8660 - val_loss: 0.4358 - val_top_k_accuracy: 0.9834
# Epoch 100/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 45s 213ms/step - accuracy: 0.9116 - loss: 0.2560 - top_k_accuracy: 0.9908 - val_accuracy: 0.8862 - val_loss: 0.4062 - val_top_k_accuracy: 0.9886
# Epoch 101/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 40s 199ms/step - accuracy: 0.9108 - loss: 0.2488 - top_k_accuracy: 0.9915 - val_accuracy: 0.8450 - val_loss: 0.6392 - val_top_k_accuracy: 0.9720
# Epoch 102/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 39s 185ms/step - accuracy: 0.9018 - loss: 0.2697 - top_k_accuracy: 0.9894 - val_accuracy: 0.8266 - val_loss: 0.6531 - val_top_k_accuracy: 0.9764
# Epoch 103/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 38s 230ms/step - accuracy: 0.9111 - loss: 0.2828 - top_k_accuracy: 0.9874 - val_accuracy: 0.8870 - val_loss: 0.5209 - val_top_k_accuracy: 0.9790
# Epoch 104/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 38s 205ms/step - accuracy: 0.9029 - loss: 0.2853 - top_k_accuracy: 0.9879 - val_accuracy: 0.8897 - val_loss: 0.3813 - val_top_k_accuracy: 0.9860
# Epoch 105/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 30s 188ms/step - accuracy: 0.9062 - loss: 0.2747 - top_k_accuracy: 0.9885 - val_accuracy: 0.8468 - val_loss: 0.7548 - val_top_k_accuracy: 0.9755
# Epoch 106/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 31s 189ms/step - accuracy: 0.8870 - loss: 0.3580 - top_k_accuracy: 0.9870 - val_accuracy: 0.8424 - val_loss: 0.6245 - val_top_k_accuracy: 0.9807
# Epoch 107/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 33s 203ms/step - accuracy: 0.9186 - loss: 0.2322 - top_k_accuracy: 0.9940 - val_accuracy: 0.8818 - val_loss: 0.3722 - val_top_k_accuracy: 0.9816
# Epoch 108/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 33s 203ms/step - accuracy: 0.9101 - loss: 0.2664 - top_k_accuracy: 0.9922 - val_accuracy: 0.8599 - val_loss: 0.4139 - val_top_k_accuracy: 0.9790
# Epoch 109/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 39s 188ms/step - accuracy: 0.9084 - loss: 0.2588 - top_k_accuracy: 0.9868 - val_accuracy: 0.8774 - val_loss: 0.4126 - val_top_k_accuracy: 0.9860
# Epoch 110/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 41s 189ms/step - accuracy: 0.9165 - loss: 0.2351 - top_k_accuracy: 0.9909 - val_accuracy: 0.8888 - val_loss: 0.3896 - val_top_k_accuracy: 0.9869
# Epoch 111/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 41s 188ms/step - accuracy: 0.9123 - loss: 0.2452 - top_k_accuracy: 0.9917 - val_accuracy: 0.8809 - val_loss: 0.3411 - val_top_k_accuracy: 0.9886
# Epoch 112/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 30s 188ms/step - accuracy: 0.9204 - loss: 0.2132 - top_k_accuracy: 0.9924 - val_accuracy: 0.8730 - val_loss: 0.3990 - val_top_k_accuracy: 0.9877
# Epoch 113/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 32s 199ms/step - accuracy: 0.9170 - loss: 0.2386 - top_k_accuracy: 0.9903 - val_accuracy: 0.8932 - val_loss: 0.4200 - val_top_k_accuracy: 0.9825
# Epoch 114/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 34s 201ms/step - accuracy: 0.9117 - loss: 0.2450 - top_k_accuracy: 0.9923 - val_accuracy: 0.8844 - val_loss: 0.4274 - val_top_k_accuracy: 0.9860
# Epoch 115/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 39s 193ms/step - accuracy: 0.9142 - loss: 0.2452 - top_k_accuracy: 0.9947 - val_accuracy: 0.8783 - val_loss: 0.4195 - val_top_k_accuracy: 0.9895
# Epoch 116/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 39s 188ms/step - accuracy: 0.9086 - loss: 0.2713 - top_k_accuracy: 0.9936 - val_accuracy: 0.8774 - val_loss: 0.3890 - val_top_k_accuracy: 0.9851
# Epoch 117/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 31s 183ms/step - accuracy: 0.9241 - loss: 0.2432 - top_k_accuracy: 0.9911 - val_accuracy: 0.8800 - val_loss: 0.3645 - val_top_k_accuracy: 0.9877
# Epoch 118/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 34s 200ms/step - accuracy: 0.9225 - loss: 0.2233 - top_k_accuracy: 0.9957 - val_accuracy: 0.8546 - val_loss: 0.5518 - val_top_k_accuracy: 0.9869
# Epoch 119/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 33s 203ms/step - accuracy: 0.9241 - loss: 0.2126 - top_k_accuracy: 0.9913 - val_accuracy: 0.8984 - val_loss: 0.3507 - val_top_k_accuracy: 0.9904
# Epoch 120/120
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 30s 188ms/step - accuracy: 0.9301 - loss: 0.1855 - top_k_accuracy: 0.9946 - val_accuracy: 0.8923 - val_loss: 0.3509 - val_top_k_accuracy: 0.9886

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(accuracy))
plt.plot(epochs, accuracy, 'b', label='Training accuracy')
plt.plot(epochs, val_accuracy, 'r', label='Validation accuracy')

plt.title('Training and validation accuracy')
plt.legend()
plt.figure()
plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')

plt.title('Training and validation loss')
plt.legend()
plt.show()

# %%
# Save the model in the Keras format
vit.save('/kaggle/working/model.keras')

# %%
vit.save_weights('/kaggle/working/model.weights.h5')

# %%
pred = vit.predict(test_dataset)
# Out:
# 41/41 [==============================] - 7s 85ms/step

# %%
vit.evaluate(test_dataset)
# Out:
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 9s 212ms/step - accuracy: 0.8862 - loss: 0.3761 - top_k_accuracy: 0.9931
# [0.39345282316207886, 0.879481315612793, 0.9908466935157776]

# %%
predicted=[]
labels=[]
for im, label in test_dataset:
    predicted.append(vit(im))
    labels.append(label.numpy())

# %%
pred= np.concatenate([np.argmax(predicted[:-1],axis=-1).flatten(),np.argmax(predicted[-1],axis=-1).flatten()])
lab= np.concatenate([np.argmax(labels[:-1],axis=-1).flatten(),np.argmax(labels[-1],axis=-1).flatten()])

# %%
plt.figure(figsize=(12,12))
for   images,labels in  test_dataset.take(10):
  for i   in range(16):
   ax=plt.subplot(4,4,i+1)

   plt.imshow(images[i]/255.)
   plt.title("True Label :"+ class_name[tf.argmax(labels[i],axis=0).numpy()] + "\n" + "Predicted:" + class_name[tf.argmax(vit(tf.expand_dims(images[i],axis=0)),axis= -1).numpy()[0]])
   plt.axis("off")

# %%
cm=confusion_matrix(lab,pred)
print(cm)
plt.figure(figsize=(8,8))
sns.heatmap(cm,annot=True)
plt.title("Confusion Matrix")
plt.ylabel('Actual')
plt.xlabel("Predicted")
# Out:
# [[226  67   0   7]
#  [ 13 264  15  14]
#  [  1  24 378   2]
#  [  1  14   0 285]]
# Text(0.5, 58.7222222222222, 'Predicted')

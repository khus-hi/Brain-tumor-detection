# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import multilabel_confusion_matrix,confusion_matrix
import seaborn as sns
from sklearn.model_selection   import train_test_split

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense,Add, Dropout, Resizing,Rescaling,InputLayer,Flatten,LayerNormalization, MultiHeadAttention

from tensorflow.keras.callbacks import Callback, EarlyStopping,ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers,Model
from tensorflow.keras.regularizers import L2
from tensorflow.keras.metrics import CategoricalAccuracy, TopKCategoricalAccuracy

from tensorflow.keras.preprocessing.image import load_img
#from tensorflow.keras.utils import plot_model
from functools import partial

# %%
import pandas as pd
#import plotly.express as px
from tensorflow.keras.layers import RandomRotation, RandomFlip, RandomContrast
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
learning_rate = 0.0001
class_name=['glioma','meningioma','notumor','pituitary']
#class_name = ['glioma_tumor', 'meningioma_tumor', 'no_tumor', 'pituitary_tumor']
weight_decay = 0.0001
num_classes=4
batch_size =32
num_epochs = 120
image_size = 225  # We'll resize input images to this size
patch_size = 15  # Size of the patches to be extract from the input images
num_patches = (image_size // patch_size) ** 2
projection_dim = 64
Num_heads = 4
transformer_units = [
    projection_dim * 2,
    projection_dim,
]  # Size of the transformer layers
num_layers = 15
Hidden_size=64
mlp_head_units = 1024

# %% [markdown]
# importing from drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile
import os

# Step 1: Extract the ZIP file to a specific folder
with zipfile.ZipFile('/content/drive/MyDrive/archive (5).zip', 'r') as zip_ref:
    zip_ref.extractall('/content/temp')

# Step 2: List the files in the extracted folder
os.listdir('/content/temp')

# Step 3: Refresh the File Explorer manually or list files again
# Out:
# ['Training', 'Testing']

# %%
# !ls /content/
# !ls /content/temp
# Out:
# drive  gdrive  sample_data  temp
# Testing  Training

# %%
train_data = r'/content/temp/Training'
test_data = r'/content/temp/Testing'

# %%
train_dataset = tf.keras.utils.image_dataset_from_directory(
    train_data,
    labels='inferred',
    label_mode='categorical',
    class_names=class_name,
    color_mode='grayscale',
    batch_size=batch_size,
    image_size=(image_size,image_size),
    shuffle=True,
    seed=99,
    validation_split=0.2,
    subset='training',
)
val_dataset = tf.keras.utils.image_dataset_from_directory(
    train_data,
    labels='inferred',
    label_mode='categorical',
    class_names=class_name,
    color_mode='grayscale',
    batch_size=batch_size,
    image_size=(image_size,image_size),
    shuffle=True,
    seed=99,
    validation_split=0.2,  # Use 20% of the data for validation
    subset='validation',
)
test_dataset = tf.keras.utils.image_dataset_from_directory(
    test_data,
    labels='inferred',
    label_mode='categorical',
    class_names=class_name,
    color_mode='grayscale',
    batch_size=batch_size,
    image_size=(image_size,image_size),
    shuffle=True,
    seed=99,
)
# Out:
# Found 5712 files belonging to 4 classes.
# Using 4570 files for training.
# Found 5712 files belonging to 4 classes.
# Using 1142 files for validation.
# Found 1311 files belonging to 4 classes.

# %%
plt.figure(figsize=(8, 8))
for images, labels in train_dataset.take(10):
    for i in range(min(16, len(images))):
        ax = plt.subplot(4, 4, i + 1)
        plt.imshow(images[i] / 255., cmap='gray')
        plt.title(class_name[tf.argmax(labels[i]).numpy()])
        plt.axis("off")

plt.show()

# %%
augment_layers = tf.keras.Sequential([
    RandomRotation(factor=(-0.25, 0.2501)),
   RandomFlip("horizontal_and_vertical",seed=42),  # Specify a seed for reproducibility
])

# %%
# Define a custom preprocessing function
def process_data(image, label):
    augmented_image=augment_layers(image)
    resized_image = tf.image.resize(augmented_image, size=(image_size, image_size))
    return resized_image, label

# Apply augmentation and preprocessing to the dataset
training_dataset = (
    train_dataset.
    shuffle(1000)
    .map(partial(process_data),num_parallel_calls=tf.data.AUTOTUNE)
    .prefetch(tf.data.AUTOTUNE)
)

# %%
vali_dataset=(
   val_dataset.shuffle(1000)
    .prefetch(tf.data.AUTOTUNE)


)

# %%
input_tensor = next(iter(training_dataset))[0]

# %%
patche=tf.image.extract_patches(images=input_tensor,
                               sizes=[1,patch_size,patch_size,1],
                                strides=[1,patch_size,patch_size,1],
                                rates=[1,1,1,1],
                                 padding='VALID')

# %%
plt.figure(figsize=(12, 12))

batch_size, patch_rows, patch_cols, channels = patche.shape
plt.subplot(1, 2, 1)
plt.imshow(input_tensor[0],cmap='gray')
plt.title('Original Image')
plt.axis('off')
plt.show()
for i in range(patch_rows):
    for j in range(patch_cols):
        ax = plt.subplot(patch_rows, patch_cols, i * patch_cols + j + 1)
        plt.imshow(patche[0, i, j, :].numpy().reshape (patch_size,patch_size, 1),cmap='gray')
        plt.axis("off")

plt.show()

# %%
class PatchEncoder(layers.Layer):
    def __init__(self, patch_size,Hidden_size):
        super(PatchEncoder, self).__init__(name='patch_encoder')
        self.linear_projection=Dense(Hidden_size)
        self.position_embedding = layers.Embedding(
            input_dim=num_patches, output_dim=Hidden_size
        )

        self.num_patches=num_patches

    def call(self, image):
        batch_size = tf.shape(image)[0]  # Retrieve batch size
        patches=tf.image.extract_patches(images=image,
                                sizes=[1,patch_size,patch_size,1],
                                strides=[1,patch_size,patch_size,1],
                                rates=[1,1,1,1],
                                 padding='VALID'
                                )

        patch_dims = patches.shape[-1]
        patches = tf.reshape(patches, [batch_size, -1, patches.shape[-1]])
        embedding_input=tf.range(start=0,limit =self.num_patches,delta=1)
        output=self.linear_projection(patches)+ self.position_embedding(embedding_input)
        return output

# %%
class TransformerEncoder(layers.Layer):
    def __init__(self, Num_heads,Hidden_size):
        super(TransformerEncoder, self).__init__(name='transformer_encoder')
        self.layer_norm_1=LayerNormalization()
        self.layer_norm_2=LayerNormalization()

        self.multi_head_att=MultiHeadAttention(Num_heads,Hidden_size)

        self.dense_1=Dense(Hidden_size,activation=tf.nn.gelu)
        self.dense_2=Dense(Hidden_size,activation=tf.nn.gelu)


    def call(self, input):
        x=self.layer_norm_1(input)
        x1=self.multi_head_att(x,x)

        x1=Add()([x1,input])
        x2=self.layer_norm_2(x1)
        x2=self.dense_1(x2)
        output=self.dense_1(x2)
        output=Add()([output,x1])

        return output

# %%
class VIT(tf.keras.Model):
    def __init__(self, Num_heads, Hidden_size, num_patches, num_layers, mlp_head_units):
        super(VIT, self).__init__(name='vision_transformer')
        self.num_layers = num_layers
        self.patch_encoder = PatchEncoder(patch_size, Hidden_size)
        self.trans_encoder = [TransformerEncoder(Num_heads, Hidden_size) for _ in range(num_layers)]
        self.flatten = layers.Flatten()
        self.dense_1 = layers.Dense(mlp_head_units, activation='relu')
        self.dense_2 = layers.Dense(mlp_head_units, activation='relu')
        self.dense_3 = layers.Dense(num_classes, activation='softmax')

    def call(self, inputs):
        x = self.patch_encoder(inputs)  # Get encoded patches
        for i in range(self.num_layers):
            x = self.trans_encoder[i](x)  # Apply transformer encoder layers

        x = self.flatten(x)
        x = self.dense_1(x)
        x = self.dense_2(x)
        output = self.dense_3(x)
        return output

# Create and compile the VIT model
vit = VIT(Num_heads, Hidden_size, num_patches, num_layers, mlp_head_units)

# %%
loss_funcion=tf.keras.losses.CategoricalCrossentropy(
    from_logits=False,

)

# %%
metrics=[CategoricalAccuracy(name= 'accuracy'),TopKCategoricalAccuracy(k=2,name='top_k_accuracy')]

# %%
vit.compile(
    optimizer=Adam(learning_rate=learning_rate),
                   loss=loss_funcion,
                   metrics=metrics

)

# %%
# Define the filepath to save the model weights
checkpoint_filepath = "/kaggle/working/checkpoint.weights.h5"

# Define the ModelCheckpoint callback
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    checkpoint_filepath,
    monitor="val_accuracy",
    save_best_only=True,
    save_weights_only=True
)

# %%
# Train the model
history = vit.fit(
    training_dataset,
    epochs=num_epochs,
    verbose=1,
    validation_data=vali_dataset,
    callbacks=[checkpoint_callback]

)
# Out:
# Epoch 1/120
# 143/143 [==============================] - 74s 218ms/step - loss: 28.5744 - accuracy: 0.4195 - top_k_accuracy: 0.7175 - val_loss: 6.8626 - val_accuracy: 0.4676 - val_top_k_accuracy: 0.7215
# Epoch 2/120
# 143/143 [==============================] - 34s 214ms/step - loss: 4.5634 - accuracy: 0.5383 - top_k_accuracy: 0.7915 - val_loss: 3.1114 - val_accuracy: 0.5359 - val_top_k_accuracy: 0.7907
# Epoch 3/120
# 143/143 [==============================] - 33s 202ms/step - loss: 2.9612 - accuracy: 0.5799 - top_k_accuracy: 0.8195 - val_loss: 2.2373 - val_accuracy: 0.6016 - val_top_k_accuracy: 0.8415
# Epoch 4/120
# 143/143 [==============================] - 33s 202ms/step - loss: 2.2705 - accuracy: 0.6066 - top_k_accuracy: 0.8361 - val_loss: 1.7863 - val_accuracy: 0.6559 - val_top_k_accuracy: 0.8757
# Epoch 5/120
# 143/143 [==============================] - 32s 193ms/step - loss: 1.9110 - accuracy: 0.6252 - top_k_accuracy: 0.8499 - val_loss: 1.8316 - val_accuracy: 0.6331 - val_top_k_accuracy: 0.8792
# Epoch 6/120
# 143/143 [==============================] - 35s 203ms/step - loss: 1.7114 - accuracy: 0.6381 - top_k_accuracy: 0.8527 - val_loss: 1.5824 - val_accuracy: 0.6594 - val_top_k_accuracy: 0.8687
# Epoch 7/120
# 143/143 [==============================] - 34s 196ms/step - loss: 1.4302 - accuracy: 0.6619 - top_k_accuracy: 0.8716 - val_loss: 1.5365 - val_accuracy: 0.6331 - val_top_k_accuracy: 0.8844
# Epoch 8/120
# 143/143 [==============================] - 32s 195ms/step - loss: 1.4016 - accuracy: 0.6534 - top_k_accuracy: 0.8665 - val_loss: 1.3443 - val_accuracy: 0.6436 - val_top_k_accuracy: 0.8669
# Epoch 9/120
# 143/143 [==============================] - 32s 195ms/step - loss: 1.2619 - accuracy: 0.6702 - top_k_accuracy: 0.8829 - val_loss: 1.4977 - val_accuracy: 0.6384 - val_top_k_accuracy: 0.8371
# Epoch 10/120
# 143/143 [==============================] - 33s 204ms/step - loss: 1.1299 - accuracy: 0.6908 - top_k_accuracy: 0.8943 - val_loss: 1.2066 - val_accuracy: 0.6655 - val_top_k_accuracy: 0.8870
# Epoch 11/120
# 143/143 [==============================] - 33s 203ms/step - loss: 1.0778 - accuracy: 0.6982 - top_k_accuracy: 0.8956 - val_loss: 1.1460 - val_accuracy: 0.6760 - val_top_k_accuracy: 0.8897
# Epoch 12/120
# 143/143 [==============================] - 34s 195ms/step - loss: 1.1290 - accuracy: 0.6873 - top_k_accuracy: 0.8967 - val_loss: 1.3323 - val_accuracy: 0.6760 - val_top_k_accuracy: 0.8862
# Epoch 13/120
# 143/143 [==============================] - 35s 206ms/step - loss: 1.0562 - accuracy: 0.7046 - top_k_accuracy: 0.9081 - val_loss: 0.9951 - val_accuracy: 0.6988 - val_top_k_accuracy: 0.8993
# Epoch 14/120
# 143/143 [==============================] - 33s 203ms/step - loss: 0.9459 - accuracy: 0.7260 - top_k_accuracy: 0.9105 - val_loss: 1.0338 - val_accuracy: 0.7180 - val_top_k_accuracy: 0.9107
# Epoch 15/120
# 143/143 [==============================] - 34s 197ms/step - loss: 0.9072 - accuracy: 0.7348 - top_k_accuracy: 0.9155 - val_loss: 1.0008 - val_accuracy: 0.7137 - val_top_k_accuracy: 0.9299
# Epoch 16/120
# 143/143 [==============================] - 32s 201ms/step - loss: 0.8885 - accuracy: 0.7420 - top_k_accuracy: 0.9149 - val_loss: 0.8997 - val_accuracy: 0.7469 - val_top_k_accuracy: 0.9326
# Epoch 17/120
# 143/143 [==============================] - 33s 203ms/step - loss: 0.8285 - accuracy: 0.7551 - top_k_accuracy: 0.9230 - val_loss: 0.9971 - val_accuracy: 0.7496 - val_top_k_accuracy: 0.9273
# Epoch 18/120
# 143/143 [==============================] - 33s 204ms/step - loss: 0.8586 - accuracy: 0.7473 - top_k_accuracy: 0.9263 - val_loss: 0.8205 - val_accuracy: 0.7644 - val_top_k_accuracy: 0.9370
# Epoch 19/120
# 143/143 [==============================] - 33s 202ms/step - loss: 0.7939 - accuracy: 0.7591 - top_k_accuracy: 0.9335 - val_loss: 0.9292 - val_accuracy: 0.7671 - val_top_k_accuracy: 0.9343
# Epoch 20/120
# 143/143 [==============================] - 32s 196ms/step - loss: 0.7915 - accuracy: 0.7713 - top_k_accuracy: 0.9376 - val_loss: 0.9582 - val_accuracy: 0.7119 - val_top_k_accuracy: 0.9221
# Epoch 21/120
# 143/143 [==============================] - 32s 195ms/step - loss: 0.7624 - accuracy: 0.7768 - top_k_accuracy: 0.9411 - val_loss: 0.9582 - val_accuracy: 0.7233 - val_top_k_accuracy: 0.9387
# Epoch 22/120
# 143/143 [==============================] - 33s 203ms/step - loss: 0.7789 - accuracy: 0.7547 - top_k_accuracy: 0.9383 - val_loss: 0.8261 - val_accuracy: 0.7680 - val_top_k_accuracy: 0.9352
# Epoch 23/120
# 143/143 [==============================] - 35s 204ms/step - loss: 0.6956 - accuracy: 0.7792 - top_k_accuracy: 0.9381 - val_loss: 0.7470 - val_accuracy: 0.7811 - val_top_k_accuracy: 0.9492
# Epoch 24/120
# 143/143 [==============================] - 33s 203ms/step - loss: 0.6721 - accuracy: 0.7891 - top_k_accuracy: 0.9444 - val_loss: 0.6654 - val_accuracy: 0.8082 - val_top_k_accuracy: 0.9475
# Epoch 25/120
# 143/143 [==============================] - 34s 209ms/step - loss: 0.6957 - accuracy: 0.7919 - top_k_accuracy: 0.9488 - val_loss: 0.9225 - val_accuracy: 0.7977 - val_top_k_accuracy: 0.9378
# Epoch 26/120
# 143/143 [==============================] - 32s 194ms/step - loss: 0.6841 - accuracy: 0.7888 - top_k_accuracy: 0.9481 - val_loss: 0.8031 - val_accuracy: 0.7732 - val_top_k_accuracy: 0.9387
# Epoch 27/120
# 143/143 [==============================] - 31s 193ms/step - loss: 0.6254 - accuracy: 0.8090 - top_k_accuracy: 0.9525 - val_loss: 0.7401 - val_accuracy: 0.7898 - val_top_k_accuracy: 0.9457
# Epoch 28/120
# 143/143 [==============================] - 32s 196ms/step - loss: 0.6603 - accuracy: 0.7943 - top_k_accuracy: 0.9473 - val_loss: 0.6344 - val_accuracy: 0.8012 - val_top_k_accuracy: 0.9501
# Epoch 29/120
# 143/143 [==============================] - 32s 195ms/step - loss: 0.6331 - accuracy: 0.8070 - top_k_accuracy: 0.9538 - val_loss: 0.5620 - val_accuracy: 0.8065 - val_top_k_accuracy: 0.9606
# Epoch 30/120
# 143/143 [==============================] - 32s 196ms/step - loss: 0.5675 - accuracy: 0.8101 - top_k_accuracy: 0.9571 - val_loss: 0.8973 - val_accuracy: 0.7636 - val_top_k_accuracy: 0.9212
# Epoch 31/120
# 143/143 [==============================] - 35s 214ms/step - loss: 0.5542 - accuracy: 0.8195 - top_k_accuracy: 0.9578 - val_loss: 0.5619 - val_accuracy: 0.8100 - val_top_k_accuracy: 0.9658
# Epoch 32/120
# 143/143 [==============================] - 34s 205ms/step - loss: 0.5658 - accuracy: 0.8276 - top_k_accuracy: 0.9626 - val_loss: 0.5485 - val_accuracy: 0.8354 - val_top_k_accuracy: 0.9615
# Epoch 33/120
# 143/143 [==============================] - 32s 194ms/step - loss: 0.5049 - accuracy: 0.8337 - top_k_accuracy: 0.9663 - val_loss: 0.5744 - val_accuracy: 0.8292 - val_top_k_accuracy: 0.9772
# Epoch 34/120
# 143/143 [==============================] - 31s 193ms/step - loss: 0.5113 - accuracy: 0.8315 - top_k_accuracy: 0.9648 - val_loss: 0.5392 - val_accuracy: 0.8345 - val_top_k_accuracy: 0.9737
# Epoch 35/120
# 143/143 [==============================] - 32s 195ms/step - loss: 0.5504 - accuracy: 0.8284 - top_k_accuracy: 0.9656 - val_loss: 0.6493 - val_accuracy: 0.8152 - val_top_k_accuracy: 0.9580
# Epoch 36/120
# 143/143 [==============================] - 35s 204ms/step - loss: 0.5170 - accuracy: 0.8330 - top_k_accuracy: 0.9665 - val_loss: 0.5456 - val_accuracy: 0.8468 - val_top_k_accuracy: 0.9790
# Epoch 37/120
# 143/143 [==============================] - 35s 205ms/step - loss: 0.5467 - accuracy: 0.8339 - top_k_accuracy: 0.9621 - val_loss: 0.5913 - val_accuracy: 0.8327 - val_top_k_accuracy: 0.9580
# Epoch 38/120
# 143/143 [==============================] - 31s 193ms/step - loss: 0.4677 - accuracy: 0.8470 - top_k_accuracy: 0.9702 - val_loss: 0.5447 - val_accuracy: 0.8310 - val_top_k_accuracy: 0.9676
# Epoch 39/120
# 143/143 [==============================] - 32s 194ms/step - loss: 0.4828 - accuracy: 0.8418 - top_k_accuracy: 0.9700 - val_loss: 0.5784 - val_accuracy: 0.8170 - val_top_k_accuracy: 0.9755
# Epoch 40/120
# 143/143 [==============================] - 32s 195ms/step - loss: 0.4912 - accuracy: 0.8389 - top_k_accuracy: 0.9672 - val_loss: 0.5680 - val_accuracy: 0.8371 - val_top_k_accuracy: 0.9606
# Epoch 41/120
# 143/143 [==============================] - 33s 194ms/step - loss: 0.4954 - accuracy: 0.8405 - top_k_accuracy: 0.9705 - val_loss: 0.5410 - val_accuracy: 0.8301 - val_top_k_accuracy: 0.9720
# Epoch 42/120
# 143/143 [==============================] - 32s 194ms/step - loss: 0.4812 - accuracy: 0.8446 - top_k_accuracy: 0.9698 - val_loss: 0.5436 - val_accuracy: 0.8389 - val_top_k_accuracy: 0.9694
# Epoch 43/120
# 143/143 [==============================] - 32s 194ms/step - loss: 0.4400 - accuracy: 0.8562 - top_k_accuracy: 0.9733 - val_loss: 0.5493 - val_accuracy: 0.8441 - val_top_k_accuracy: 0.9667
# Epoch 44/120
# 143/143 [==============================] - 34s 196ms/step - loss: 0.4600 - accuracy: 0.8420 - top_k_accuracy: 0.9757 - val_loss: 0.5974 - val_accuracy: 0.8170 - val_top_k_accuracy: 0.9694
# Epoch 45/120
# 143/143 [==============================] - 31s 193ms/step - loss: 0.5079 - accuracy: 0.8385 - top_k_accuracy: 0.9698 - val_loss: 0.5850 - val_accuracy: 0.8179 - val_top_k_accuracy: 0.9606
# Epoch 46/120
# 143/143 [==============================] - 32s 195ms/step - loss: 0.4676 - accuracy: 0.8444 - top_k_accuracy: 0.9681 - val_loss: 0.6685 - val_accuracy: 0.8117 - val_top_k_accuracy: 0.9510
# Epoch 47/120
# 143/143 [==============================] - 31s 194ms/step - loss: 0.4355 - accuracy: 0.8586 - top_k_accuracy: 0.9753 - val_loss: 0.5548 - val_accuracy: 0.8257 - val_top_k_accuracy: 0.9685
# Epoch 48/120
# 143/143 [==============================] - 32s 194ms/step - loss: 0.4250 - accuracy: 0.8648 - top_k_accuracy: 0.9770 - val_loss: 0.4881 - val_accuracy: 0.8336 - val_top_k_accuracy: 0.9737
# Epoch 49/120
# 143/143 [==============================] - 31s 194ms/step - loss: 0.4335 - accuracy: 0.8532 - top_k_accuracy: 0.9751 - val_loss: 0.6578 - val_accuracy: 0.8380 - val_top_k_accuracy: 0.9588
# Epoch 50/120
# 143/143 [==============================] - 35s 202ms/step - loss: 0.4337 - accuracy: 0.8554 - top_k_accuracy: 0.9764 - val_loss: 0.4888 - val_accuracy: 0.8520 - val_top_k_accuracy: 0.9685
# Epoch 51/120
# 143/143 [==============================] - 34s 204ms/step - loss: 0.3861 - accuracy: 0.8702 - top_k_accuracy: 0.9803 - val_loss: 0.5333 - val_accuracy: 0.8450 - val_top_k_accuracy: 0.9615
# Epoch 52/120
# 143/143 [==============================] - 33s 194ms/step - loss: 0.4104 - accuracy: 0.8637 - top_k_accuracy: 0.9770 - val_loss: 0.5621 - val_accuracy: 0.8520 - val_top_k_accuracy: 0.9658
# Epoch 53/120
# 143/143 [==============================] - 34s 205ms/step - loss: 0.4189 - accuracy: 0.8615 - top_k_accuracy: 0.9764 - val_loss: 0.6387 - val_accuracy: 0.8319 - val_top_k_accuracy: 0.9729
# Epoch 54/120
# 143/143 [==============================] - 34s 206ms/step - loss: 0.4255 - accuracy: 0.8586 - top_k_accuracy: 0.9757 - val_loss: 0.6388 - val_accuracy: 0.8301 - val_top_k_accuracy: 0.9545
# Epoch 55/120
# 143/143 [==============================] - 32s 194ms/step - loss: 0.3727 - accuracy: 0.8656 - top_k_accuracy: 0.9836 - val_loss: 0.5784 - val_accuracy: 0.8424 - val_top_k_accuracy: 0.9641
# Epoch 56/120
# 143/143 [==============================] - 32s 194ms/step - loss: 0.3897 - accuracy: 0.8720 - top_k_accuracy: 0.9818 - val_loss: 0.7479 - val_accuracy: 0.8065 - val_top_k_accuracy: 0.9405
# Epoch 57/120
# 143/143 [==============================] - 35s 213ms/step - loss: 0.3838 - accuracy: 0.8735 - top_k_accuracy: 0.9792 - val_loss: 0.4704 - val_accuracy: 0.8669 - val_top_k_accuracy: 0.9737
# Epoch 58/120
# 143/143 [==============================] - 32s 194ms/step - loss: 0.4033 - accuracy: 0.8672 - top_k_accuracy: 0.9761 - val_loss: 0.5316 - val_accuracy: 0.8494 - val_top_k_accuracy: 0.9685
# Epoch 59/120
# 143/143 [==============================] - 32s 194ms/step - loss: 0.3736 - accuracy: 0.8650 - top_k_accuracy: 0.9807 - val_loss: 0.5052 - val_accuracy: 0.8205 - val_top_k_accuracy: 0.9650
# Epoch 60/120
# 143/143 [==============================] - 32s 195ms/step - loss: 0.3688 - accuracy: 0.8716 - top_k_accuracy: 0.9812 - val_loss: 0.4634 - val_accuracy: 0.8529 - val_top_k_accuracy: 0.9755
# Epoch 61/120
# 143/143 [==============================] - 34s 208ms/step - loss: 0.3471 - accuracy: 0.8803 - top_k_accuracy: 0.9825 - val_loss: 0.4812 - val_accuracy: 0.8389 - val_top_k_accuracy: 0.9737
# Epoch 62/120
# 143/143 [==============================] - 31s 194ms/step - loss: 0.3315 - accuracy: 0.8856 - top_k_accuracy: 0.9834 - val_loss: 0.4609 - val_accuracy: 0.8494 - val_top_k_accuracy: 0.9746
# Epoch 63/120
# 143/143 [==============================] - 31s 194ms/step - loss: 0.3747 - accuracy: 0.8753 - top_k_accuracy: 0.9821 - val_loss: 0.5531 - val_accuracy: 0.8581 - val_top_k_accuracy: 0.9694
# Epoch 64/120
# 143/143 [==============================] - 32s 195ms/step - loss: 0.3941 - accuracy: 0.8711 - top_k_accuracy: 0.9772 - val_loss: 0.5373 - val_accuracy: 0.8231 - val_top_k_accuracy: 0.9842
# Epoch 65/120
# 143/143 [==============================] - 32s 195ms/step - loss: 0.3419 - accuracy: 0.8818 - top_k_accuracy: 0.9853 - val_loss: 0.5075 - val_accuracy: 0.8476 - val_top_k_accuracy: 0.9755
# Epoch 66/120
# 143/143 [==============================] - 32s 195ms/step - loss: 0.3521 - accuracy: 0.8803 - top_k_accuracy: 0.9818 - val_loss: 0.4360 - val_accuracy: 0.8546 - val_top_k_accuracy: 0.9772
# Epoch 67/120
# 143/143 [==============================] - 32s 195ms/step - loss: 0.3309 - accuracy: 0.8788 - top_k_accuracy: 0.9832 - val_loss: 0.4597 - val_accuracy: 0.8441 - val_top_k_accuracy: 0.9720
# Epoch 68/120
# 143/143 [==============================] - 34s 208ms/step - loss: 0.3151 - accuracy: 0.8897 - top_k_accuracy: 0.9851 - val_loss: 0.4418 - val_accuracy: 0.8616 - val_top_k_accuracy: 0.9799
# Epoch 69/120
# 143/143 [==============================] - 31s 193ms/step - loss: 0.3601 - accuracy: 0.8755 - top_k_accuracy: 0.9823 - val_loss: 0.4523 - val_accuracy: 0.8660 - val_top_k_accuracy: 0.9781
# Epoch 70/120
# 143/143 [==============================] - 31s 194ms/step - loss: 0.3262 - accuracy: 0.8827 - top_k_accuracy: 0.9849 - val_loss: 0.4881 - val_accuracy: 0.8660 - val_top_k_accuracy: 0.9772
# Epoch 71/120
# 143/143 [==============================] - 32s 197ms/step - loss: 0.3030 - accuracy: 0.8921 - top_k_accuracy: 0.9877 - val_loss: 0.4492 - val_accuracy: 0.8669 - val_top_k_accuracy: 0.9772
# Epoch 72/120
# 143/143 [==============================] - 32s 196ms/step - loss: 0.3409 - accuracy: 0.8834 - top_k_accuracy: 0.9847 - val_loss: 0.6452 - val_accuracy: 0.8275 - val_top_k_accuracy: 0.9571
# Epoch 73/120
# 143/143 [==============================] - 31s 195ms/step - loss: 0.3363 - accuracy: 0.8823 - top_k_accuracy: 0.9810 - val_loss: 0.4739 - val_accuracy: 0.8459 - val_top_k_accuracy: 0.9825
# Epoch 74/120
# 143/143 [==============================] - 33s 194ms/step - loss: 0.3115 - accuracy: 0.8915 - top_k_accuracy: 0.9867 - val_loss: 0.5170 - val_accuracy: 0.8608 - val_top_k_accuracy: 0.9737
# Epoch 75/120
# 143/143 [==============================] - 34s 206ms/step - loss: 0.3330 - accuracy: 0.8904 - top_k_accuracy: 0.9823 - val_loss: 0.4297 - val_accuracy: 0.8581 - val_top_k_accuracy: 0.9729
# Epoch 76/120
# 143/143 [==============================] - 32s 196ms/step - loss: 0.3224 - accuracy: 0.8882 - top_k_accuracy: 0.9860 - val_loss: 0.4801 - val_accuracy: 0.8616 - val_top_k_accuracy: 0.9807
# Epoch 77/120
# 143/143 [==============================] - 32s 195ms/step - loss: 0.3012 - accuracy: 0.8956 - top_k_accuracy: 0.9858 - val_loss: 0.6457 - val_accuracy: 0.8485 - val_top_k_accuracy: 0.9632
# Epoch 78/120
# 143/143 [==============================] - 32s 195ms/step - loss: 0.3269 - accuracy: 0.8882 - top_k_accuracy: 0.9836 - val_loss: 0.4191 - val_accuracy: 0.8599 - val_top_k_accuracy: 0.9799
# Epoch 79/120
# 143/143 [==============================] - 33s 202ms/step - loss: 0.3328 - accuracy: 0.8873 - top_k_accuracy: 0.9853 - val_loss: 0.4451 - val_accuracy: 0.8765 - val_top_k_accuracy: 0.9746
# Epoch 80/120
# 143/143 [==============================] - 32s 196ms/step - loss: 0.3043 - accuracy: 0.8891 - top_k_accuracy: 0.9873 - val_loss: 0.5248 - val_accuracy: 0.8485 - val_top_k_accuracy: 0.9737
# Epoch 81/120
# 143/143 [==============================] - 31s 194ms/step - loss: 0.3169 - accuracy: 0.8873 - top_k_accuracy: 0.9891 - val_loss: 0.4496 - val_accuracy: 0.8730 - val_top_k_accuracy: 0.9816
# Epoch 82/120
# 143/143 [==============================] - 35s 204ms/step - loss: 0.2914 - accuracy: 0.8965 - top_k_accuracy: 0.9884 - val_loss: 0.5314 - val_accuracy: 0.8564 - val_top_k_accuracy: 0.9807
# Epoch 83/120
# 143/143 [==============================] - 32s 195ms/step - loss: 0.2943 - accuracy: 0.8950 - top_k_accuracy: 0.9847 - val_loss: 0.5454 - val_accuracy: 0.8310 - val_top_k_accuracy: 0.9764
# Epoch 84/120
# 143/143 [==============================] - 31s 194ms/step - loss: 0.3039 - accuracy: 0.8982 - top_k_accuracy: 0.9856 - val_loss: 0.4508 - val_accuracy: 0.8529 - val_top_k_accuracy: 0.9764
# Epoch 85/120
# 143/143 [==============================] - 32s 196ms/step - loss: 0.3198 - accuracy: 0.8958 - top_k_accuracy: 0.9851 - val_loss: 0.4625 - val_accuracy: 0.8722 - val_top_k_accuracy: 0.9685
# Epoch 86/120
# 143/143 [==============================] - 33s 203ms/step - loss: 0.3168 - accuracy: 0.8888 - top_k_accuracy: 0.9851 - val_loss: 0.4163 - val_accuracy: 0.8774 - val_top_k_accuracy: 0.9807
# Epoch 87/120
# 143/143 [==============================] - 32s 195ms/step - loss: 0.2749 - accuracy: 0.9074 - top_k_accuracy: 0.9891 - val_loss: 0.4787 - val_accuracy: 0.8441 - val_top_k_accuracy: 0.9816
# Epoch 88/120
# 143/143 [==============================] - 32s 194ms/step - loss: 0.2804 - accuracy: 0.8998 - top_k_accuracy: 0.9873 - val_loss: 0.6701 - val_accuracy: 0.8573 - val_top_k_accuracy: 0.9667
# Epoch 89/120
# 143/143 [==============================] - 32s 194ms/step - loss: 0.2943 - accuracy: 0.9046 - top_k_accuracy: 0.9858 - val_loss: 0.4882 - val_accuracy: 0.8555 - val_top_k_accuracy: 0.9746
# Epoch 90/120
# 143/143 [==============================] - 34s 207ms/step - loss: 0.2747 - accuracy: 0.9018 - top_k_accuracy: 0.9891 - val_loss: 0.5289 - val_accuracy: 0.8730 - val_top_k_accuracy: 0.9781
# Epoch 91/120
# 143/143 [==============================] - 34s 206ms/step - loss: 0.2575 - accuracy: 0.9059 - top_k_accuracy: 0.9923 - val_loss: 0.5725 - val_accuracy: 0.8643 - val_top_k_accuracy: 0.9746
# Epoch 92/120
# 143/143 [==============================] - 32s 200ms/step - loss: 0.2515 - accuracy: 0.9083 - top_k_accuracy: 0.9893 - val_loss: 0.4375 - val_accuracy: 0.8827 - val_top_k_accuracy: 0.9764
# Epoch 93/120
# 143/143 [==============================] - 32s 195ms/step - loss: 0.2346 - accuracy: 0.9112 - top_k_accuracy: 0.9912 - val_loss: 0.4596 - val_accuracy: 0.8730 - val_top_k_accuracy: 0.9807
# Epoch 94/120
# 143/143 [==============================] - 32s 195ms/step - loss: 0.2564 - accuracy: 0.9044 - top_k_accuracy: 0.9895 - val_loss: 0.5338 - val_accuracy: 0.8660 - val_top_k_accuracy: 0.9799
# Epoch 95/120
# 143/143 [==============================] - 31s 194ms/step - loss: 0.2579 - accuracy: 0.9090 - top_k_accuracy: 0.9886 - val_loss: 0.4085 - val_accuracy: 0.8792 - val_top_k_accuracy: 0.9790
# Epoch 96/120
# 143/143 [==============================] - 32s 195ms/step - loss: 0.2710 - accuracy: 0.9070 - top_k_accuracy: 0.9884 - val_loss: 0.5768 - val_accuracy: 0.8538 - val_top_k_accuracy: 0.9790
# Epoch 97/120
# 143/143 [==============================] - 32s 195ms/step - loss: 0.2516 - accuracy: 0.9090 - top_k_accuracy: 0.9917 - val_loss: 0.5432 - val_accuracy: 0.8616 - val_top_k_accuracy: 0.9816
# Epoch 98/120
# 143/143 [==============================] - 33s 193ms/step - loss: 0.2585 - accuracy: 0.9112 - top_k_accuracy: 0.9904 - val_loss: 0.5288 - val_accuracy: 0.8424 - val_top_k_accuracy: 0.9842
# Epoch 99/120
# 143/143 [==============================] - 33s 196ms/step - loss: 0.2720 - accuracy: 0.9079 - top_k_accuracy: 0.9908 - val_loss: 0.4206 - val_accuracy: 0.8809 - val_top_k_accuracy: 0.9737
# Epoch 100/120
# 143/143 [==============================] - 34s 200ms/step - loss: 0.2315 - accuracy: 0.9193 - top_k_accuracy: 0.9917 - val_loss: 0.5232 - val_accuracy: 0.8783 - val_top_k_accuracy: 0.9764
# Epoch 101/120
# 143/143 [==============================] - 32s 195ms/step - loss: 0.2578 - accuracy: 0.9109 - top_k_accuracy: 0.9906 - val_loss: 0.4645 - val_accuracy: 0.8660 - val_top_k_accuracy: 0.9711
# Epoch 102/120
# 143/143 [==============================] - 32s 202ms/step - loss: 0.2368 - accuracy: 0.9151 - top_k_accuracy: 0.9915 - val_loss: 0.4827 - val_accuracy: 0.8888 - val_top_k_accuracy: 0.9825
# Epoch 103/120
# 143/143 [==============================] - 33s 204ms/step - loss: 0.2261 - accuracy: 0.9177 - top_k_accuracy: 0.9930 - val_loss: 0.4375 - val_accuracy: 0.8914 - val_top_k_accuracy: 0.9869
# Epoch 104/120
# 143/143 [==============================] - 34s 197ms/step - loss: 0.2539 - accuracy: 0.9125 - top_k_accuracy: 0.9904 - val_loss: 0.5605 - val_accuracy: 0.8862 - val_top_k_accuracy: 0.9790
# Epoch 105/120
# 143/143 [==============================] - 31s 194ms/step - loss: 0.2745 - accuracy: 0.9057 - top_k_accuracy: 0.9910 - val_loss: 0.4504 - val_accuracy: 0.8818 - val_top_k_accuracy: 0.9842
# Epoch 106/120
# 143/143 [==============================] - 35s 217ms/step - loss: 0.2750 - accuracy: 0.9120 - top_k_accuracy: 0.9873 - val_loss: 0.4372 - val_accuracy: 0.8870 - val_top_k_accuracy: 0.9825
# Epoch 107/120
# 143/143 [==============================] - 38s 210ms/step - loss: 0.2474 - accuracy: 0.9083 - top_k_accuracy: 0.9899 - val_loss: 0.5005 - val_accuracy: 0.8853 - val_top_k_accuracy: 0.9895
# Epoch 108/120
# 143/143 [==============================] - 38s 223ms/step - loss: 0.2359 - accuracy: 0.9210 - top_k_accuracy: 0.9912 - val_loss: 0.5112 - val_accuracy: 0.8792 - val_top_k_accuracy: 0.9869
# Epoch 109/120
# 143/143 [==============================] - 31s 194ms/step - loss: 0.2449 - accuracy: 0.9151 - top_k_accuracy: 0.9899 - val_loss: 0.4994 - val_accuracy: 0.8678 - val_top_k_accuracy: 0.9869
# Epoch 110/120
# 143/143 [==============================] - 32s 195ms/step - loss: 0.2266 - accuracy: 0.9173 - top_k_accuracy: 0.9910 - val_loss: 0.4722 - val_accuracy: 0.8669 - val_top_k_accuracy: 0.9807
# Epoch 111/120
# 143/143 [==============================] - 32s 196ms/step - loss: 0.2300 - accuracy: 0.9193 - top_k_accuracy: 0.9919 - val_loss: 0.4347 - val_accuracy: 0.8879 - val_top_k_accuracy: 0.9834
# Epoch 112/120
# 143/143 [==============================] - 33s 202ms/step - loss: 0.2181 - accuracy: 0.9228 - top_k_accuracy: 0.9928 - val_loss: 0.4016 - val_accuracy: 0.9037 - val_top_k_accuracy: 0.9886
# Epoch 113/120
# 143/143 [==============================] - 32s 195ms/step - loss: 0.2187 - accuracy: 0.9219 - top_k_accuracy: 0.9923 - val_loss: 0.4555 - val_accuracy: 0.8914 - val_top_k_accuracy: 0.9860
# Epoch 114/120
# 143/143 [==============================] - 32s 197ms/step - loss: 0.2174 - accuracy: 0.9236 - top_k_accuracy: 0.9934 - val_loss: 0.4802 - val_accuracy: 0.8818 - val_top_k_accuracy: 0.9869
# Epoch 115/120
# 143/143 [==============================] - 34s 205ms/step - loss: 0.2248 - accuracy: 0.9239 - top_k_accuracy: 0.9934 - val_loss: 0.5291 - val_accuracy: 0.8511 - val_top_k_accuracy: 0.9825
# Epoch 116/120
# 143/143 [==============================] - 34s 206ms/step - loss: 0.2056 - accuracy: 0.9245 - top_k_accuracy: 0.9941 - val_loss: 0.4612 - val_accuracy: 0.8967 - val_top_k_accuracy: 0.9869
# Epoch 117/120
# 143/143 [==============================] - 31s 195ms/step - loss: 0.2081 - accuracy: 0.9245 - top_k_accuracy: 0.9958 - val_loss: 0.4246 - val_accuracy: 0.8932 - val_top_k_accuracy: 0.9869
# Epoch 118/120
# 143/143 [==============================] - 31s 194ms/step - loss: 0.2101 - accuracy: 0.9221 - top_k_accuracy: 0.9950 - val_loss: 0.4356 - val_accuracy: 0.8888 - val_top_k_accuracy: 0.9895
# Epoch 119/120
# 143/143 [==============================] - 32s 194ms/step - loss: 0.1967 - accuracy: 0.9317 - top_k_accuracy: 0.9943 - val_loss: 0.6598 - val_accuracy: 0.8555 - val_top_k_accuracy: 0.9772
# Epoch 120/120
# 143/143 [==============================] - 32s 196ms/step - loss: 0.2198 - accuracy: 0.9254 - top_k_accuracy: 0.9930 - val_loss: 0.5543 - val_accuracy: 0.8809 - val_top_k_accuracy: 0.9772

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(accuracy))
plt.plot(epochs, accuracy, 'b', label='Training accuracy')
plt.plot(epochs, val_accuracy, 'r', label='Validation accuracy')

plt.title('Training and validation accuracy')
plt.legend()
plt.figure()
plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')

plt.title('Training and validation loss')
plt.legend()
plt.show()

# %%
# Save the model in the Keras format
vit.save('/kaggle/working/model.keras')

# %%
vit.save_weights('/kaggle/working/model.weights.h5')

# %%
pred = vit.predict(test_dataset)
# Out:
# 41/41 [==============================] - 7s 85ms/step

# %%
vit.evaluate(test_dataset)
# Out:
# 41/41 [==============================] - 3s 74ms/step - loss: 0.6414 - accuracy: 0.8558 - top_k_accuracy: 0.9832
# [0.641381025314331, 0.8558352589607239, 0.9832189083099365]

# %%
predicted=[]
labels=[]
for im, label in test_dataset:
    predicted.append(vit(im))
    labels.append(label.numpy())

# %%
pred= np.concatenate([np.argmax(predicted[:-1],axis=-1).flatten(),np.argmax(predicted[-1],axis=-1).flatten()])
lab= np.concatenate([np.argmax(labels[:-1],axis=-1).flatten(),np.argmax(labels[-1],axis=-1).flatten()])

# %%
plt.figure(figsize=(12,12))
for   images,labels in  test_dataset.take(10):
  for i   in range(16):
   ax=plt.subplot(4,4,i+1)

   plt.imshow(images[i]/255.)
   plt.title("True Label :"+ class_name[tf.argmax(labels[i],axis=0).numpy()] + "\n" + "Predicted:" + class_name[tf.argmax(vit(tf.expand_dims(images[i],axis=0)),axis= -1).numpy()[0]])
   plt.axis("off")

# %%
cm=confusion_matrix(lab,pred)
print(cm)
plt.figure(figsize=(8,8))
sns.heatmap(cm,annot=True)
plt.title("Confusion Matrix")
plt.ylabel('Actual')
plt.xlabel("Predicted")
# Out:
# [[206  79   2  13]
#  [ 10 238  43  15]
#  [  0   3 402   0]
#  [  2  18   4 276]]
# Text(0.5, 58.7222222222222, 'Predicted')
